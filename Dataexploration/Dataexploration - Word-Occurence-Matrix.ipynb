# %%
import pandas as pd
import pickle

# %%
df = pickle.load( open( "word_occurence_matrix_18000.p", "rb" ))

# %%
df
# Out:
#               you       a     the       i      to      rt   bitch     and  \
# all        7593.0  6299.0  5039.0  4774.0  3828.0  3567.0  2784.0  2762.0
# hate       5124.0  2117.0  1169.0  1050.0   978.0   231.0   208.0   804.0
# offensive  1547.0  2394.0  1513.0  1970.0  1175.0  1874.0  2562.0   868.0
# neutral     922.0  1788.0  2357.0  1754.0  1675.0  1462.0    14.0  1090.0
#
#                is    that ...   httptcodyQTJtlg  httptcodyYvrEJAm  \
# all        2347.0  2182.0 ...               1.0               1.0
# hate        656.0   543.0 ...               0.0               0.0
# offensive   611.0   868.0 ...               0.0               0.0
# neutral    1080.0   771.0 ...               1.0               1.0
#
#            httptcodyawomzlu\n\n\nhttpstcotxoflj  httptcoeAGkXDGH  \
# all                                         1.0              1.0
# hate                                        0.0              0.0
# ...

# %%
df['niggah']
# Out:
# all          93.0
# hate         18.0
# offensive    75.0
# neutral       0.0
# Name: niggah, dtype: float64

# %%
dfT = df.T

# %%
dfT[(dfT['offensive']==0.0) & (dfT['neutral']==0.0)]
# Out:
#                        all  hate  offensive  neutral
# istandwithhatespeech  55.0  55.0        0.0      0.0
# trump                 44.0  44.0        0.0      0.0
# whitepower            42.0  42.0        0.0      0.0
# 🖕                     41.0  41.0        0.0      0.0
# 🏼                     20.0  20.0        0.0      0.0
# kys                   17.0  17.0        0.0      0.0
# 🤔                     14.0  14.0        0.0      0.0
# ye                    14.0  14.0        0.0      0.0
# 🏻                     13.0  13.0        0.0      0.0
# jew                   13.0  13.0        0.0      0.0
# utter                 12.0  12.0        0.0      0.0
# xd                    12.0  12.0        0.0      0.0
# 🙄                     12.0  12.0        0.0      0.0
#                       11.0   0.0        0.0      0.0
# scottish               7.0   7.0        0.0      0.0
# limey                  7.0   7.0        0.0      0.0
# blackpeoplesuck        7.0   7.0        0.0      0.0
# ...

# %%
from gensim.models import FastText
import numpy as np
path = r'G:\Fasttext\cc.en.300.bin\\cc.en.300.bin'
def get_compare_vectors(w1, w2):
    vectors = FastText.load_fasttext_format(path, encoding='utf-8')
    ev1=vectors.wv[w1]
    ev2 = vectors.wv[w2]
    print(type(ev1))
    print(ev1==ev2)
    print(np.array_equal(ev1, ev2))
# Out:
# c:\users\thora\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
get_compare_vectors('nigger', 'niggah')
# Out:
# <class 'numpy.ndarray'>
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
# ...
