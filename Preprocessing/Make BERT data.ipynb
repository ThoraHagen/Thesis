# %%
from gensim.models import FastText
import pandas as pd
import numpy as np
import itertools
import html
import pickle
import regex as re

from sklearn.metrics import confusion_matrix
from nltk.tokenize import TweetTokenizer
from collections import Counter
from emoji import UNICODE_EMOJI
import emoji
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# c:\users\thora\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
def load_data(csv, p1, p2):
    """
    Loads data from 3 specific paths. 
    Returns a list of texts, a corresponding list of labels (0|1|2), and a labels counter.
    """
    df = pd.read_csv(csv, index_col=0, encoding = 'utf-8')

    texts = []
    labels = []
    for row in df.itertuples(index=True):
        tweet = getattr(row, "tweet")
        classif = getattr(row, "classification")
        texts.append(tweet)
        labels.append(classif)

    more_hateful_tweets = pickle.load(open(p1, "rb" ))
    more_clean_tweets = pickle.load(open(p2, "rb" ))

    hateful_labels = [0] * len(more_hateful_tweets)
    clean_labels = [2] * len(more_clean_tweets)
    print('Additional Hateful:', len(more_hateful_tweets), 'Additional Clean:', len(more_clean_tweets))
    
    texts = texts+more_hateful_tweets+more_clean_tweets
    labels = labels+hateful_labels+clean_labels
    
    texts, labels = drop_duplicates(texts, labels)
    cnt = Counter(labels)
    print(cnt)
    return texts, labels, cnt

# %%
def drop_duplicates(texts, labels):
    """ Removes duplicate entries."""
    single_texts = []
    single_labels = []

    duplicates = 0
    for i, text in enumerate(texts):
        if text not in single_texts:

            single_texts.append(text)
            single_labels.append(labels[i])
        else:
            duplicates += 1
    return single_texts, single_labels

# %%
def convert_html_emojis(corpus):
    new_corpus = []
    for text in corpus:
        text = html.unescape(text)
        new_corpus.append(text)
    return new_corpus

# %%
def tokenize_texts(corpus, stopword_path = None):
    """
    Tokenizes a list of texts. ...!
    """
    corpus = convert_html_emojis(corpus)
    print(corpus[:10])
    tknzr = TweetTokenizer(preserve_case=False, reduce_len=True, strip_handles=True)
    
    
    token_doc_list = []
    token_list = []
   
    for text in corpus:
       # text = re.sub(r'https?:\/\/\S*', ' ', text)

        tokens = tknzr.tokenize(text)
        tokens2 = []
        for token in tokens:
            token = re.sub(r'([1234567890!"#$%&()*+,./:@;?[\]^`{|}_~\t\n])', '', token)
            if token != '':
                tokens2.append(token)
        
        #text = re.sub(r'([1234567890!"#$%&()*+,./:;?[\]^`{|}_~\t\n])', ' ', text) #handles and hashtag
        #tokens = tknzr.tokenize(text)
        
        tmp_tokens = []
        for i, token in enumerate(tokens2):
            if token in UNICODE_EMOJI:
               
                emoji_one = emoji.demojize(token)
                emoji_one = emoji_one[1:-1]
                emoji_all = re.split('_', emoji_one)

                tokens[i] = emoji_all
                token_list.extend(emoji_all)
                tmp_tokens.extend(emoji_all)
            elif token == "i'd":
                token_list.extend(['i', 'would'])
                tmp_tokens.extend(['i', 'would'])
            else: 
                token_list.append(token)
                tmp_tokens.append(token)

            
        token_doc_list.append(tmp_tokens)     
            
    #index, mfws, max_words = find_most_common(token_list)
   
    #if stopword_path == None: stopwords = []
    #else: stopwords = read_stopwords(stopword_path)
    #new_texts = fit_index_on_texts(index, token_doc_list, stopwords, mfws) 
    return token_doc_list

# %%
texts, labels, cnt = load_data('offensive_language_crowdflower.csv', "tweets_hate_icwsm18_extended.p", "tweets_clean_zeerakW_extended.p")
# Out:
# Additional Hateful: 9802 Additional Clean: 3017
# Counter({1: 19190, 0: 11185, 2: 7180})

# %%
texts[:10]
# Out:
# ["!!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...",
#  '!!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!',
#  '!!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit',
#  '!!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny',
#  '!!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;',
#  '!!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just blows me..claim you so faithful and down for somebody but still fucking with hoes! &#128514;&#128514;&#128514;"',
#  '!!!!!!"@__BrighterDays: I can not just sit up and HATE on another bitch .. I got too much shit going on!"',
#  "!!!!&#8220;@selfiequeenbri: cause I'm tired of you big bitches coming for us skinny girls!!&#8221;",
#  '" &amp; you might not get ya bitch back &amp; thats that "',
#  '" @rhythmixx_ :hobbies include: fighting Mariam"\n\nbitch']

# %%
maxlen = 100
token_doc_list = tokenize_texts(texts)
# Out:
# ["!!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. & as a man you should always take the trash out...", '!!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!', '!!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit', '!!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny', '!!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya \ue011', '!!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just blows me..claim you so faithful and down for somebody but still fucking with hoes! 😂😂😂"', '!!!!!!"@__BrighterDays: I can not just sit up and HATE on another bitch .. I got too much shit going on!"', "!!!!“@selfiequeenbri: cause I'm tired of you big bitches coming for us skinny girls!!”", '" & you might not get ya bitch back & thats that "', '" @rhythmixx_ :hobbies include: fighting Mariam"\n\nbitch']

# %%
token_doc_list[:10]
# Out:
# [['rt',
#   'as',
#   'a',
#   'woman',
#   'you',
#   "shouldn't",
#   'complain',
#   'about',
#   'cleaning',
#   'up',
#   'your',
#   'house',
#   'as',
#   'a',
#   'man',
#   'you',
#   'should',
#   'always',
#   'take',
#   'the',
#   'trash',
#   'out'],
#  ['rt',
#   'boy',
#   'dats',
#   'cold',
#   'tyga',
#   'dwn',
#   'bad',
#   'for',
#   'cuffin',
#   'dat',
#   'hoe',
#   'in',
#   'the',
#   'st',
#   'place'],
#  ['rt',
#   'dawg',
#   'rt',
#   'you',
#   'ever',
#   'fuck',
#   'a',
#   'bitch',
#   'and',
#   'she',
#   'start',
#   'to',
#   'cry',
#   'you',
#   'be',
#   'confused',
#   'as',
#   'shit'],
#  ['rt', 'she', 'look', 'like', 'a', 'tranny'],
#  ['rt',
#   'the',
#   'shit',
#   'you',
#   'hear',
#   'about',
#   'me',
#   'might',
#   'be',
#   'true',
#   'or',
#   'it',
#   'might',
#   'be',
#   'faker',
#   'than',
#   'the',
#   'bitch',
#   'who',
#   'told',
#   'it',
#   'to',
#   'ya',
#   '\ue011'],
#  ['the',
#   'shit',
#   'just',
#   'blows',
#   'me',
#   'claim',
#   'you',
#   'so',
#   'faithful',
#   'and',
#   'down',
#   'for',
#   'somebody',
#   'but',
#   'still',
#   'fucking',
#   'with',
#   'hoes',
#   'face',
#   'with',
#   'tears',
#   'of',
#   'joy',
#   'face',
#   'with',
#   'tears',
#   'of',
#   'joy',
#   'face',
#   'with',
#   'tears',
#   'of',
#   'joy'],
#  ['i',
#   'can',
#   'not',
#   'just',
#   'sit',
#   'up',
#   'and',
#   'hate',
#   'on',
#   'another',
#   'bitch',
#   'i',
#   'got',
#   'too',
#   'much',
#   'shit',
#   'going',
#   'on'],
#  ['“',
#   'cause',
#   "i'm",
#   'tired',
#   'of',
#   'you',
#   'big',
#   'bitches',
#   'coming',
#   'for',
#   'us',
#   'skinny',
#   'girls',
#   '”'],
#  ['you', 'might', 'not', 'get', 'ya', 'bitch', 'back', 'thats', 'that'],
#  ['hobbies', 'include', 'fighting', 'mariam', 'bitch']]

# %%
new_texts = []
for t in token_doc_list:
    text = " ".join(t)
    new_texts.append(text)

# %%
new_texts[:20]
# Out:
# ["rt as a woman you shouldn't complain about cleaning up your house as a man you should always take the trash out",
#  'rt boy dats cold tyga dwn bad for cuffin dat hoe in the st place',
#  'rt dawg rt you ever fuck a bitch and she start to cry you be confused as shit',
#  'rt she look like a tranny',
#  'rt the shit you hear about me might be true or it might be faker than the bitch who told it to ya \ue011',
#  'the shit just blows me claim you so faithful and down for somebody but still fucking with hoes face with tears of joy face with tears of joy face with tears of joy',
#  'i can not just sit up and hate on another bitch i got too much shit going on',
#  "“ cause i'm tired of you big bitches coming for us skinny girls ”",
#  'you might not get ya bitch back thats that',
#  'hobbies include fighting mariam bitch',
#  'keeks is a bitch she curves everyone lol i walked into a conversation like this smh',
#  'murda gang bitch its gang land',
#  'so hoes that smoke are losers yea go on ig',
#  'bad bitches is the only thing that i like',
#  'bitch get up off me',
#  'bitch nigga miss me with it',
#  'bitch plz whatever',
#  'bitch who do you love',
#  'bitches get cut off everyday b',
#  'black bottle a bad bitch']

# %%
df = pd.DataFrame(columns=['label', 'text'])

# %%
len(df)
# Out:
# 0

# %%
for i, text in enumerate(new_texts):
    df = df.append({'label': labels[i], 'text':text}, ignore_index=True)

# %%
#df.to_csv('hatespeech_preprocessed_full.tsv', sep='\t')

# %%
pd.set_option('max_colwidth', 150)

# %%
df_sorted = df.sort_values(by=['label'])

# %%
df_0 = df_sorted[df_sorted['label'] == 0]
df_1 = df_sorted[df_sorted['label'] == 1]
df_2 = df_sorted[df_sorted['label'] == 2]

# %%
df_0[:100]
# Out:
#       label  \
# 33389     0
# 26571     0
# 26570     0
# 26569     0
# 26568     0
# 26567     0
# 26566     0
# 26565     0
# 26564     0
# 26563     0
# 7460      0
# 26562     0
# 26561     0
# 26560     0
# 26559     0
# 26558     0
# 26557     0
# 26556     0
# 26572     0
# 26573     0
# 26574     0
# 26575     0
# 26592     0
# 26591     0
# 26590     0
# 7432      0
# 26589     0
# 26588     0
# 26587     0
# 26586     0
# ...     ...
# 26547     0
# 26546     0
# 26545     0
# 26544     0
# 26532     0
# 26543     0
# 26541     0
# 26540     0
# 26539     0
# 26538     0
# 26537     0
# 26536     0
# 26535     0
# 26534     0
# 26542     0
# 26512     0
# 26594     0
# 26596     0
# 26655     0
# 26654     0
# 26653     0
# 26652     0
# 26651     0
# 26650     0
# 26649     0
# 26648     0
# 7372      0
# 26647     0
# 26646     0
# 26645     0
#
#                                                                                                                                  text
# 33389     bruh honestly no one cares ur a little scrawny arab indian cunt anyone can put you into the ground so shut ya fucking mouth
# 26571                                                                                                        imp your retard strength
# 26570                                                                                                probably because ur a blind cunt
# 26569    nowadays questioning any group of people is considered hate speech when did society become so sensitive istandwithhatespeech
# 26568                                                                         you are basically saying my cunt fav dug your grave yas
# 26567         free software foundation does not cover copywriting its upto an author whether it will be copyrighted or not you faggot
# 26566                                                                                     truth istandwithhatespeech httpstcoHoXRxtly
# 26565          rt istandwithhatespeech because the legal definition of hate speech depends on what offends the regime in power erdo …
# 26564                                                                                                               fuck off you cunt
# 26563                                                                        the emoji makes you hundred points percent more retarded
# 7460                                   a nicca say he ballin ask em where his title n his deeds at not wher his clothes n his keys at
# 26562                                                        askbeau would you like to come to argentina and tweet us a selfie cunt x
# 26561                                                                                                your a arena scrub cunt fuck off
# 26560                                                                                                      just you fuckin relax cunt
# 26559          as far as i know city almost signed him and close to medical   \ nwtf now why you retarded people including us in that
# 26558  increase followers on twitter \ nhttps tcoiidylqhbu\ncodecon agtpremiere mayaandmarty istandwithhatespeech mybestfriendinwords
# 26557                                                                                                     shut up andy you weird cunt
# 26556                                                                   that was president bush you cunt thanksobama blametheblackguy
# 26572                                                                                              i never blocked you you silly cunt
# 26573                                                                                                           shut up you ugly cunt
# 26574                                                                                                   you cunt pistol pistol pistol
# 26575       fuck u cunt there was a reason u were banned i think u should be banned again u uncivilized prick notch isx better than u
# 26592                                                                                                      what did u hit bald retard
# 26591                                                                                                     liked your own video faggot
# 26590                                                                          history is full of walls that worked you fuckin retard
# 7432                  a guy claiming to be republican called c-span news and said republicans hate that nigger obama httpstcoXZeuguZM
# 26589                                                                        as big as your hands you priceless twat httpstcoSJBrmgUw
# 26588                                fucken gay cunt nice way to show respect towards your lgbt fans middle finger loudly crying face
# 26587                                                                                                       right next to you ya cunt
# 26586                                                                         u took my words and twisted them ur actually the retard
# ...                                                                                                                               ...
# 26547                                                                                                            cos ur a noncey twat
# 26546                                                                 attention seeking chelsea twat go and wank on ur small oil club
# 26545                                                               yunho already beat you to it and ate me like a course meal faggot
# 26544                                                                              hahahahaha you put way too much stock in your twat
# 26532                                                                                                   haha dipping cunt ur that bad
# 26543                                                                             what the actual fuck are you saying you cheeky cunt
# 26541                                                                                                 why am i not in this u fat cunt
# 26540                                                                                     you cancerous cunt gtfo youtube endblaziken
# 26539                                                                                                              shut up you nigger
# 26538                                                               your retarded theres a thing called self defence or fighting back
# 26537                                               boy you look like a retarded goldfish getcha spicy meatball head ass outta here b
# 26536                                                 i have the right to call you a faggot nothing will happen to me lol hate speech
# 26535                                                                                                                 and your a twat
# 26534                                                   well you fucking deserve it for skipping out on the comic you illiterate cunt
# 26542                  holy shit you know i consider you mother fuckers crazy before but damn you done went full retard httpstcouFQWZ
# 26512                                                                                    mr snuffleupagus have you always been a cunt
# 26594                                                                                           you mean the redneck hood like you no
# 26596                                                    you mean the ones where white trash had president hung on trees with a noose
# 26655                  don \ ' t you love it when a retarded feminist degrades you to the simple term of being an egg lmao gtfo honey
# 26654                                                                                           u win the faggot award congrats yay <
# 26653                             you are clearly retarded where are you going to get the money for m work force legal wages benefits
# 26652                 excuse me languge and where have i insulted you i explained i have dyslexia i am no retard how fucking dare you
# 26651                                                                                         racist white sc rich white trash u suck
# 26650                                                                                       lmao i now have trust issues bc of u cunt
# 26649                                                             show us your taxes keep your children out of the white house faggot
# 26648                                                                                             proper cunt you are you fat bastard
# 7372                                                              what's this chinks email i'm moving to china and slicing his throat
# 26647                                                                                                             get out then u cunt
# 26646                                                   fuck you cunt middle finger 🏻 middle finger 🏻 middle finger 🏻 middle finger 🏻
# 26645               bore off now you wetwipe saying the same thing face with tears of joy low intelligence levels for a law grad cunt
#
# [100 rows x 2 columns]

# %%
df_0 = df_0.sample(frac=1)
df_1 = df_1.sample(frac=1)
df_2 = df_2.sample(frac=1)

# %%
df_2[:6]

# %%
cnt

# %%
print(len(df_0), len(df_1), len(df_2))
# Out:
# 11185 19190 7180

# %%
train_df = df_0[:4000].append([df_1[:4000], df_2[:4000]])
test_df = df_0[4000:5000].append([df_1[4000:5000], df_2[4000:5000]])
dev_df = df_0[5000:6000].append([df_1[5000:6000], df_2[5000:6000]])

# %%
len(train_df)
# Out:
# 12000

# %%
len(test_df)
# Out:
# 3000

# %%
len(dev_df)
# Out:
# 3000

# %%
train_df = train_df.sample(frac=1)
test_df = test_df.sample(frac=1)
dev_df = dev_df.sample(frac=1)

# %%
train_df.to_csv('hatespeech_final_train.tsv', sep='\t')
test_df.to_csv('hatespeech_final_test.tsv', sep='\t')
dev_df.to_csv('hatespeech_final_dev.tsv', sep='\t')

# %%
train_df[:20]
# Out:
#       label  \
# 31330     0
# 10327     1
# 30293     0
# 23466     2
# 35879     2
# 8544      1
# 27936     0
# 25418     0
# 2379      1
# 6847      1
# 5689      2
# 34415     0
# 26846     0
# 18817     2
# 30730     0
# 18873     1
# 21948     1
# 26677     0
# 28531     0
# 31305     0
#
#                                                                                                      text
# 31330                                                                   wow classy language you cunt nazi
# 10327                                                               i get gwop now that bitch remember me
# 30293                 u guys are fucking mentally retarded wasting my time plz rechall for this shit lmao
# 23466                                            you're black your name looks hungarian you marry a hunky
# 35879                                                       where did i call you stupid show me the tweet
# 8544                              crazy ass rt i been acting so mean ratchet and ghetto i crack myself up
# 27936  everything about and everything you do with the queens is retarded go king go is a retardest chant
# 25418                                          tan is short for tania not the other way around you retard
# 2379                i've seen a number of bitches on here say there's no such thing as loose pussy lol ok
# 6847                                             yeah i would want to shoot the son of a bitch myself lol
# 5689                                                                   that's a cute and fuzzy one hehehe
# 34415                                                                     you always go full retard kappa
# 26846                                                                    ur a cunt face with tears of joy
# 18817                                                         rt beanies for life ◡ ̈ ⃝ httptcoiywPwmPGTu
# 30730                                                on twitter not texting me back you little twat i see
# 18873      rt slow rap voice that bitch can suck my dick faster rapping voice that bitch can suck my dick
# 21948                                       this bitch brought me my food and said surprise thirsty bitch
# 26677                                                            its a preseason game you absolute retard
# 28531                                                       dont speak if u dont know anything you retard
# 31305                                                          your a true redneck face with tears of joy

# %%
lines = train_df.values.tolist()

# %%
lines[:5]

# %%
for (i, line) in enumerate(lines[:5]):
    text_a = str(line[1])
    label = str(line[0])

# %%
lines[0]
