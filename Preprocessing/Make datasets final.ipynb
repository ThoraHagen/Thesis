# %%
import pandas as pd

# %%
from hatespeech import preprocessing
texts, labels, cnt = preprocessing.load_data('offensive_language_crowdflower.csv', "tweets_hate_icwsm18_extended.p", "tweets_clean_zeerakW_extended.p")
# Out:
# c:\users\thora\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.
# Additional Hateful: 9802 Additional Clean: 3017
# Counter({1: 19190, 0: 11185, 2: 7180})

# %%
df = pd.DataFrame(columns=['label', 'text'])

# %%
for i, text in enumerate(texts):
    df = df.append({'label': labels[i], 'text':text}, ignore_index=True)

# %%
df_0 = df[df['label'] == 0]
df_1 = df[df['label'] == 1]
df_2 = df[df['label'] == 2]

# %%
df_0 = df_0.sample(frac=1)
df_1 = df_1.sample(frac=1)
df_2 = df_2.sample(frac=1)

# %%
train_df = df_0[:4000].append([df_1[:4000], df_2[:4000]])
test_df = df_0[4000:5000].append([df_1[4000:5000], df_2[4000:5000]])
dev_df = df_0[5000:6000].append([df_1[5000:6000], df_2[5000:6000]])

# %%
len(train_df)
# Out:
# 12000

# %%
df_0_cut = df_0[:6000]
df_1_cut = df_1[:6000]
df_2_cut = df_2[:6000]

# %%
with open('offensive.txt', 'w', encoding='utf-8') as f:
    for item in list(df_1_cut["text"]):
        f.write("%s\n" % item)

# %%
train_df = df_0_cut[:4000].append([df_1_cut[:4000], df_2_cut[:4000]])
test_df = df_0_cut[4000:5000].append([df_1_cut[4000:5000], df_2_cut[4000:5000]])
dev_df = df_0_cut[5000:6000].append([df_1_cut[5000:6000], df_2_cut[5000:6000]])

# %%
train_df = train_df.sample(frac=1)
test_df = test_df.sample(frac=1)
dev_df = dev_df.sample(frac=1)

# %%
train_df
# Out:
#       label                                               text
# 7561      2              All I did was said her weed was trash
# 28145     0                 @dailydoseofadri fuck you faggot !
# 9564      1            Gotta smile dat drive bad bitches crazy
# 13736     2  Our female guinea pig is pregnant &#127882;&#1...
# 32324     0  @majorhansel That shit you just typed was fuck...
# 35628     2   @speitsch @kirindave no. singularity university.
# 516       1  "LMFAOOOOOOOOOOOOOOOOOO @bb_brooks: If your pu...
# 25171     0  @Liberal_Lunacy \n&gt; "gamers of color"\n&gt;...
# 35418     2  rt @adriarichards: i regret talking with @jonr...
# 25371     0  @MattDahDon you should have money in  your umg...
# 7442      2  A light, tender yellow butter cake with a clas...
# 11525     1  If a chick wants me to eat her pussy then leav...
# 18216     1  RT @ZOEPASSION Niggaz buying p***y....Niggaz b...
# 25914     0          @tmhdank get off me you little faggot dog
# ...

# %%
dev_df.to_csv('dev_data.csv', sep='\t')
